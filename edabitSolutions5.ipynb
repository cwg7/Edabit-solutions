# %% [markdown]
# ## 1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def is_symmetrical(num):
	newStr = str(num)
	return newStr[::-1] == newStr

# %%
if __name__=="__main__":
	print(is_symmetrical(12321))
# Out:
# True

# %% [markdown]
# ## 2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def square_digits(n):
	return int("".join(str(int(i)**2) for i in str(n)))

# %%
if __name__=="__main__":
	print(square_digits(9119))
# Out:
# 811181

# %%
## alternative solution with iteration:

# %%
def square_digits(n):
    ans = ''
    for i in str(n):
        ans += str(int(i)**2)
    return int(ans)

# %%
if __name__=="__main__":
	print(square_digits(9119))
# Out:
# 811181

# %%
## by index:

# %%
def square_digits(n):
	ans = ""
	n = str(n)
	for i in range(len(n)):
		ans += str(int(n[i]) ** 2)
	return int(ans)

# %%
if __name__=="__main__":
	print(square_digits(2483))
# Out:
# 416649

# %% [markdown]
# ## 3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def worm_length(worm):
    count = 0
    if len(worm) == 0:
        return 'invalid'
    for i in worm:
        if i != '-':
            return 'invalid'
        else:
            count +=1
    tot = count * 10
    return str(tot) + ' mm.'

# %%
if __name__=="__main__":
	print(worm_length("----------"))
# Out:
# 100 mm.

# %% [markdown]
# ## 4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math

def paths(n):
	return math.factorial(n)

# %%
if __name__=="__main__":
	print(paths(9))
# Out:
# 362880

# %% [markdown]
# ## 5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def eda_bit(start, end):
	newLst = []
	for i in range(start, end+1):
		if i % 3 == 0 and i % 5 == 0:
			newLst.append('EdaBit')
		elif i % 3 == 0:
			newLst.append('Eda')
		elif i % 5 == 0:
			newLst.append('Bit')
		else:
			newLst.append(i)
	return newLst

# %%
if __name__=="__main__":
	print(eda_bit(14,20))
# Out:
# [14, 'EdaBit', 16, 17, 'Eda', 19, 'Bit']

# %%
## more condensed solution:

# %%
def eda_bit(start, end):
	newLst = []
	for x in range(start, end+1):
		if x%3 == 0 and x%5 == 0: newLst.append('EdaBit')
		elif x%3 == 0: newLst.append('Eda')
		elif x%5 == 0: newLst.append('Bit')
		else: newLst.append(x)
	return newLst

# %%
if __name__=="__main__":
	print(eda_bit(14,20))
# Out:
# [14, 'EdaBit', 16, 17, 'Eda', 19, 'Bit']

# %% [markdown]
# ## 6)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def count_palindromes(num1, num2):
    count = 0
    for i in range(num1, num2 +1):
        if str(i) == str(i)[::-1]:
            count +=1
    return count

# %%
if __name__=="__main__":
	print(count_palindromes(10,22))
# Out:
# 2

# %% [markdown]
# ## 7)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def color_invert(rgb):
	return (255 - rgb[0], 255 - rgb[1], 255 - rgb[2])

# %%
if __name__=="__main__":
	print(color_invert((255,255,255)))
# Out:
# (0, 0, 0)

# %% [markdown]
# ## 7)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def upload_count(dates, month):
	count = 0
	for i in dates:
		if month in i:
			count +=1
	return count

# %%
if __name__=="__main__":
	print(upload_count(["Sept 22", "Sept 21", "Oct 15"], "Sept"))
# Out:
# 2

# %%
## one line solution:

# %%
def upload_count(dates, month):
	return str(dates).count(month)

# %%
if __name__=="__main__":
	print(upload_count(["Sept 22", "Sept 21", "Oct 15"], "Sept"))
# Out:
# 2

# %% [markdown]
# ## 8)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def get_student_names(students):
	newLst = list(students.values())
	return sorted(newLst)

# %%
if __name__=="__main__":
	print(get_student_names({"Student 1" : "Steve", 
                        "Student 2" : "Becky",
                        "Student 3" : "John"}))
# Out:
# ['Becky', 'John', 'Steve']

# %% [markdown]
# ## 9)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def mean(num):
	sum1 = 0
	for i in str(num):
		sum1+= int(i)
	length = len(str(num))
	return round(sum1/length)

# %%
if __name__=="__main__":
	print(mean(12345))
# Out:
# 3
