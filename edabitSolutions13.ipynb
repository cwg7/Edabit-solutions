# %% [markdown]
# ## 1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def count_overlapping(intervals, point):
	count = 0
	currMin = 0
	currMax = 0
	for i in intervals:
		currMin = min(i)
		currMax = max(i)
		if point >= currMin and point <= currMax:
			count +=1
	return count

# %%
if __name__=='__main__':
	print(count_overlapping([[1, 2], [5, 6], [5, 7]], 5))
# Out:
# 2

# %%
## second solution:

# %%
def count_overlapping(intervals, point):
	count=0
	for x in intervals:
		if point>= x[0] and point<=x[1]:
			count+=1
	return count

# %%
if __name__=='__main__':
	print(count_overlapping([[1, 2], [5, 6], [5, 7]], 5))
# Out:
# 2

# %% [markdown]
# ## 2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def duplicates(txt):
	return len(txt) - len(set(txt))

# %%
if __name__=='__main__':
	print(duplicates("The Quick Brown Fox Jumps Over the Lazy Dog"))
# Out:
# 14

# %% [markdown]
# ## 3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def oddish_or_evenish(num):
	newLst = [str(i) for i in str(num)]
	newLst2 = [int(i) for i in str(num)]
	return 'Oddish' if sum(newLst2)%2 != 0 else 'Evenish'

# %%
if __name__=='__main__':
	print(oddish_or_evenish(43))
# Out:
# Oddish

# %%
## second solution:

# %%
def oddish_or_evenish(num):
	return 'Oddish' if sum(map(int, str(num))) % 2 else 'Evenish'

# %%
if __name__=='__main__':
	print(oddish_or_evenish(43))
# Out:
# Oddish

# %% [markdown]
# ## 4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def histogram(lst, char):
	result = ''
	x = len(lst)
	for i in lst:
		if x != 1:
			result += i* char + '\n'
			x-=1
		else:
			result += i* char
	return result

# %%
if __name__=='__main__':
	print(histogram([1, 3, 4], "#"))
# Out:
# #
# ###
# ####

# %%
## second solution:

# %%
def histogram(lst, char):
	return "\n".join(char * i for i in lst)

# %%
if __name__=='__main__':
	print(histogram([1, 3, 4], "#"))
# Out:
# #
# ###
# ####

# %% [markdown]
# ## 5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def progress_days(runs):
	index1=0
	index2=1
	x = len(runs)
	count = 0
	while x > 1:
		if runs[index2] > runs[index1]:
			count +=1
			index1 +=1
			index2 +=1
			x -=1
		else:
			index1+=1
			index2+=1
			x-=1
	return count

# %%
if __name__=='__main__':
	print(progress_days([3, 4, 1, 2]))
# Out:
# 2

# %%
## better solution:

# %%
def progress_days(runs):
	result = 0
	for i in range(1,len(runs)):
		if runs[i] > runs[i-1]:
			result += 1
	return result

# %%
if __name__=='__main__':
	print(progress_days([3, 4, 1, 2]))
# Out:
# 2

# %% [markdown]
# ## 6)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def square_patch(n):
	newLst = []
	x = n
	while x > 0:
		newLst.append([int(n) for n in str(n) * n])
		x-=1
	return newLst

# %%
if __name__=='__main__':
	print(square_patch(3))
# Out:
# [[3, 3, 3], [3, 3, 3], [3, 3, 3]]

# %%
## second solution:

# %%
def square_patch(n):
	return [[n]*n]*n

# %%
if __name__=='__main__':
	print(square_patch(3))
# Out:
# [[3, 3, 3], [3, 3, 3], [3, 3, 3]]

# %% [markdown]
# ## 7)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
def neutralise(s1, s2):
	result = ''
	for i in range(len(s1)):
		if s1[i] == s2[i]:
			result += s1[i]
		else:
			result += '0'
	return result

# %%
if __name__=='__main__':
    print(neutralise("--++--", "++--++"))
# Out:
# 000000

# %%
## second solution:

# %%
def neutralise(s1, s2):
	return ''.join(a if a == b else '0' for a, b in zip(s1, s2))

# %%
if __name__=='__main__':
    print(neutralise("--++--", "++--++"))
# Out:
# 000000

# %% [markdown]
# ## 8)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def longest_word(s):
	newLst = list(s.split())
	longest = 0
	result = ''
	for i in newLst:
		if len(i) > longest:
			longest = len(i)
			result = i
	return result

# %%
if __name__=='__main__':
    print(longest_word("Margaret's toy is a pretty doll."))
# Out:
# Margaret's

# %%
## second solution:

# %%
def longest_word(s):
	return max(s.split(), key=len)

# %%
if __name__=='__main__':
    print(longest_word("Margaret's toy is a pretty doll."))
# Out:
# Margaret's

# %% [markdown]
# ## 9)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def num_of_sublists(lst):
    return sum(1 for i in lst if type(i)==list)

# %%
if __name__=='__main__':
    print(num_of_sublists([[1, 2, 3], [1, 2, 3], [1, 2, 3]]))
# Out:
# 3

# %% [markdown]
# ## 10)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import math
def i_sqrt(n):
	count = 0
	if n < 0:
		return 'invalid'
	while n >= 2:
		n= math.sqrt(n)
		count +=1
	return count

# %%
if __name__=='__main__':
    print(i_sqrt(2))
# Out:
# 1

# %% [markdown]
# ## 11)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def censor(s):
	newLst = list(s.split())
	lst2 = []
	for i in newLst:
		if len(i) > 4:
			i = '*' * len(i)
			lst2.append(i)
		else:
			lst2.append(i)
	return ' '.join(lst2)

# %%
if __name__=='__main__':
    print(censor("The code is fourty"))
# Out:
# The code is ******

# %%
## second solution:

# %%
def censor(s):
	return ' '.join('*'*len(i) if len(i) > 4 else i for i in s.split())

# %%
if __name__=='__main__':
    print(censor("The code is fourty"))
# Out:
# The code is ******

# %% [markdown]
# ## 12)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def consonants(word):
	vowels = 'aeiou'
	rest = 'bcdfghjklmnpqrstvwxyz'
	count = 0
	for i in word.lower():
		if i not in vowels and i in rest:
			count +=1
	return count

def vowels(word):
	vowels = 'aeiou'
	count = 0
	for i in word.lower():
		if i in vowels:
			count +=1
	return count

# %%
if __name__=='__main__':
    print(vowels('Jameel SAEB'))
# Out:
# 5

# %%
if __name__=='__main__':
    print(consonants('He|\o mY Fr*end'))
# Out:
# 7

# %%
## cleaner solution:

# %%
def consonants(word):
    return sum(c.lower() not in 'aeiou' for c in word if c.isalpha())

def vowels(word):
    return sum(c.lower() in 'aeiou' for c in word)

# %%
if __name__=='__main__':
    print(vowels('Jameel SAEB'))
# Out:
# 5

# %%
if __name__=='__main__':
    print(consonants('He|\o mY Fr*end'))
# Out:
# 7

# %% [markdown]
# ## 13)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def mystery_func(num):
	toStr = str(num)
	newLst = list(int(i)for i in toStr)
	result = 1
	for i in newLst:
		result *= i
	return result

# %%
if __name__=='__main__':
    print(mystery_func(152))
# Out:
# 10

# %%
## second solution:

# %%
def mystery_func(num):
	prod = 1
	for i in str(num):
		prod *= int(i)
	return prod

# %%
if __name__=='__main__':
    print(mystery_func(152))
# Out:
# 10

# %% [markdown]
# ## 14)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def digit_occurrences(start, end, digit):
	newLst = []
	for i in range(start, end+1):
		newLst.append(i)
	lst2 = list(str(i) for i in newLst)
	newStr = ''.join(lst2)
	return newStr.count(str(digit))

# %%
if __name__=='__main__':
    print(digit_occurrences(51, 55, 5))
# Out:
# 6

# %%
## second solution:

# %%
def digit_occurrences(start, end, digit):
    return ''.join(str(i) for i in range(start,end+1)).count(str(digit))

# %%
if __name__=='__main__':
    print(digit_occurrences(51, 55, 5))
# Out:
# 6
