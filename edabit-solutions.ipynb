# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def is_curzon(num):
	a = 2 ** num + 1
	b = 2 * num + 1
	
	if a % b == 0:
		return True
	else:
		return False

# %% [markdown]
# ### cleaner solution:

# %%
def is_curzon(num):
	return (2**num + 1) % (2*num + 1) == 0
