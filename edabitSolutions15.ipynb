# %% [markdown]
# ## 1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
def logarithm(base, num):
    try:
        return math.log(num,base)
    except: return 'Invalid'

# %%
if __name__=='__main__':
    print(logarithm(5, 25))
# Out:
# 2.0

# %% [markdown]
# ## 2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from datetime import date

def is_valid_date(d, m, y):
	try: d = date(y, m, d)
	except: return False
	return True

# %%
if __name__=='__main__':
    print(is_valid_date(34,2,2020))
# Out:
# False

# %% [markdown]
# ## 3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def reversed_binary_integer(num):
	binNum =  bin(num)[2:]
	revBinNum = str(binNum)[::-1]
	return int(revBinNum,2)

# %%
if __name__=='__main__':
    print(reversed_binary_integer(10))
# Out:
# 5

# %% [markdown]
# ## 4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def extend_vowels(word, num):
	vowels = 'aeiouAEIOU'
	result = ''
	if num< 0 or type(num)!= int:
		return 'invalid'
	for i in word:
		if i in vowels:
			result += i * (num+1)
		else:
			result += i
	return result

# %%
if __name__=='__main__':
    print(extend_vowels("Hello", 5))
# Out:
# Heeeeeelloooooo

# %%
## second solution:

# %%
def extend_vowels(word, num):
	return ''.join((i*num)+i if i in 'aeiouAEIOU' else i for i in word) if num>=0 and int(num)==num else 'invalid'

# %%
if __name__=='__main__':
    print(extend_vowels("Hello", 5))
# Out:
# Heeeeeelloooooo

# %% [markdown]
# ## 5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def pentagonal(num):
	x = 1
	dots = 1
	while x < num:
		dots += 5*x
		x+=1
	return dots

# %%
if __name__=='__main__':
    print(pentagonal(8))
# Out:
# 141

# %%
## second solution:

# %%
def pentagonal(num):
	ans = 1
	for i in range(1,num):
		ans += (5*i)
	return ans

# %%
if __name__=='__main__':
    print(pentagonal(8))
# Out:
# 141

# %% [markdown]
# ## 6)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def encrypt(word):
	codes = {'a':'0','e':'1','i':'2','o':'2','u':'3'}
	revWord = word[::-1]
	result = ''
	for i in revWord:
		if i in codes:
			i = codes[i]
			result += i
		else:
			result += i
	return result + 'aca'

# %%
if __name__=='__main__':
    print(encrypt("banana"))
# Out:
# 0n0n0baca

# %%
## second solution:

# %%
def encrypt(word):
	return word[::-1].translate(str.maketrans('aeou', '0123')) + 'aca'

# %%
if __name__=='__main__':
    print(encrypt("banana"))
# Out:
# 0n0n0baca

# %% [markdown]
# ## 7)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from datetime import date
def has_friday_13(month, year):
	return date(year,month,13).strftime("%A")=='Friday'

# %%
if __name__=='__main__':
    print(has_friday_13(3, 2020))
# Out:
# True

# %% [markdown]
# ## 8)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def consecutive_combo(lst1, lst2):
	lst3= list(lst1 + lst2)
	lst3 = sorted(lst3)
	return max(lst3) - min(lst3) == len(lst3)-1

# %%
if __name__=='__main__':
    print(consecutive_combo([7, 4, 5, 1], [2, 3, 6]))
# Out:
# True

# %% [markdown]
# ## 9)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = {'#': 5, 'O': 3, 'X': 1, '!': -1, '!!': -3, '!!!': -5}
def check_score(s):
    return max(0, sum(score[val] for row in s for val in row))

# %%
if __name__=='__main__':
    print(check_score([
  ["#", "!"],
  ["!!", "X"]]))
# Out:
# 2
