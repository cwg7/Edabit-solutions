# %% [markdown]
# ## 1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def happiness_number(s):
	return s.count(':)') + s.count('(:') - s.count(':(') - s.count('):')

# %%
if __name__ == '__main__':
    print(happiness_number(":):("))
# Out:
# -1

# %% [markdown]
# ## 2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def circular_shift(lst1, lst2, n):
	return lst2 == lst1[n:]+lst1[:n]

# %%
if __name__ == '__main__':
    print(circular_shift([1, 2, 3, 4], [3, 4, 1, 2], 2))
# Out:
# True

# %% [markdown]
# ## 3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def decimal_part(n):
	nStr = str(n)
	lst = list(nStr.split('.'))
	val = int(lst[-1])
	return 0 if len(lst) == 1 else val/(10** len(lst[-1]))

# %%
if __name__ == '__main__':
    print(decimal_part(-3.73))
# Out:
# 0.73

# %% [markdown]
# ## 4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def will_fit(holds, cargo):
	tot = 0
	for i in holds:
		if i == 'M':
			tot +=100
		elif i == 'L':
			tot += 200
		else:
			tot+=0
	return sum(cargo)<tot

# %%
if __name__ == '__main__':
    print(will_fit(["M", "L", "L", "M"], [56, 62, 84, 90]))
# Out:
# True

# %%
## second solution:

# %%
def will_fit(holds, cargo):
	d = {'S': 50, 'M': 100, 'L': 200}
	return sum(d[i] for i in holds) >= sum(cargo)

# %%
if __name__ == '__main__':
    print(will_fit(["M", "L", "L", "M"], [56, 62, 84, 90]))
# Out:
# True

# %% [markdown]
# ## 5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def right_triangle(x, y, z):
	lst = sorted([x,y,z])
	for i in lst:
		if i<=0:
			return False
		else:
			return lst[0]**2 + lst[1]**2 == lst[2]**2

# %%
if __name__ == '__main__':
    print(right_triangle(3, 4, 5))
# Out:
# True

# %%
## second solution:

# %%
def right_triangle(*l):
	a,b,c=sorted(l)
	return a>0and a*a+b*b==c*c

# %%
if __name__ == '__main__':
    print(right_triangle(3, 4, 5))
# Out:
# True
